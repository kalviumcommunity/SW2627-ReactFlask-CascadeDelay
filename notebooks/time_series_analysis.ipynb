# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/raw/daily_revenue.csv")
df["date"] = pd.to_datetime(df["date"], format="%Y-%m-%d")
df = df.sort_values("date")

df.head()

# %% [markdown]
# # Time Series Revenue Analysis
#
# This notebook analyzes daily revenue using resampling,
# rolling averages, month-over-month changes, and cumulative
# revenue metrics.
#
# The objective is to separate short-term daily noise from
# the underlying business trend.
